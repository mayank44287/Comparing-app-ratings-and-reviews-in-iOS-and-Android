# %%
import re
from google_play_scraper import Sort, reviews
import pandas as pd
from itertools import chain
import json

# %%
url = 'https://play.google.com/store/apps/details?id=com.herzick.houseparty&hl=en_US&showAllReviews=true&showAllReviews=true'
p = re.compile(".+\\bdetails\\?id=([^&]+)")
result = p.search(url)

appid = result.group(1)

# %%
#test
result, continuation_token = reviews(
    'com.herzick.houseparty',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
    )

# %%
def get_review(url_string):
    p = re.compile(".+\\bdetails\\?id=([^&]+)")
    result = p.search(url_string)
    appid = result.group(1)
    
    result, continuation_token = reviews(
    appid,
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=100, # defaults to 100
    #filter_score_with=5 # defaults to None(means all score)
    )
    
    #dataframe for app reviews
    '''
    df_app = pd.DataFrame(result)
    
    #drop stuff you don't need
    del df_app['userImage']
    del df_app['reviewCreatedVersion']
    del df_app['repliedAt']
    del df_app['replyContent']
    del df_app['userName']
    df_app.columns = ['at', 'content', 'score', 'thumbsUpCount']
    
    print(df_app)
    return df_app
    '''
    
    for element in result:
        element['appId'] = appid
        
    return result

# %%
#opening the appsid file
#extract appids from urls

try:
    with open('appsid', 'r') as aid:
        urls = aid.readline().split(',')

except IOError:
    print('Error while opening App\'s ID file. make sure that\
    you have a file named "appsid" in the irectory of this\
    scrip and you have right permissions to access file. \nExiting...')
    
length = len(urls)
#master dataframe
columns = ['at', 'content', 'score', 'thumbsUpCount']

app_data_list = []


while length:
    try:
        for url in urls:
            app_data = get_review(url.strip('\"'))
            app_data_list.append(app_data)
            print(str(length) + ' apps left')
            length -= 1
    except IOError as e:
        print('Operation Failed Error...')
        pass
# Out:
# 79 apps left
# 78 apps left
# 77 apps left
# 76 apps left
# 75 apps left
# 74 apps left
# 73 apps left
# 72 apps left
# 71 apps left
# 70 apps left
# 69 apps left
# 68 apps left
# 67 apps left
# 66 apps left
# 65 apps left
# 64 apps left
# 63 apps left
# 62 apps left
# 61 apps left
# 60 apps left
# 59 apps left
# 58 apps left
# 57 apps left
# 56 apps left
# 55 apps left
# 54 apps left
# 53 apps left
# 52 apps left
# 51 apps left
# 50 apps left
# 49 apps left
# 48 apps left
# 47 apps left
# 46 apps left
# 45 apps left
# 44 apps left
# 43 apps left
# 42 apps left
# 41 apps left
# 40 apps left
# 39 apps left
# 38 apps left
# 37 apps left
# 36 apps left
# 35 apps left
# 34 apps left
# 33 apps left
# 32 apps left
# 31 apps left
# 30 apps left
# 29 apps left
# 28 apps left
# 27 apps left
# 26 apps left
# 25 apps left
# 24 apps left
# 23 apps left
# 22 apps left
# 21 apps left
# 20 apps left
# 19 apps left
# 18 apps left
# 17 apps left
# 16 apps left
# 15 apps left
# 14 apps left
# 13 apps left
# 12 apps left
# 11 apps left
# 10 apps left
# 9 apps left
# 8 apps left
# 7 apps left
# 6 apps left
# 5 apps left
# 4 apps left
# 3 apps left
# 2 apps left
# 1 apps left

# %%
df = pd.DataFrame(list(chain.from_iterable(app_data_list)))
display(df)
# Out:
#                 userName                                          userImage  \
# 0     charlotte mcdonald  https://lh3.googleusercontent.com/a-/AOh14Gg2b...
# 1             Tommy Pham  https://lh3.googleusercontent.com/a-/AOh14GgRY...
# 2         Tatiana Sumari  https://lh3.googleusercontent.com/-N9VDzM5LW7Y...
# 3                 Andrew  https://lh3.googleusercontent.com/a-/AOh14GjIo...
# 4            Ross Meegan  https://lh3.googleusercontent.com/a-/AOh14Ghqn...
# ...                  ...                                                ...
# 7863         Foss Family  https://lh3.googleusercontent.com/-q2knQBrv7_Y...
# 7864       Andrew Childs  https://lh3.googleusercontent.com/a-/AOh14GgbD...
# 7865         Marisa Fulk  https://lh3.googleusercontent.com/-nWTt4FdE6Go...
# 7866     Zombie Killer76  https://lh3.googleusercontent.com/a-/AOh14Gi_c...
# 7867           grounds28  https://lh3.googleusercontent.com/-2ayEnsD_Vj4...
#
#                                                 content  score  thumbsUpCount  \
# 0     It's a good app, when it works! I've had House...      3            309
# 1     This app is pretty smooth when it comes to vid...      3            290
# 2     Not the best features. It is very flimsy with ...      2            199
# 3     Great. Very reminiscent of Skype on computers ...      4             67
# 4     Certain parts of this are great, the concept a...      3            160
# ...                                                 ...    ...            ...
# 7863  Wont stream the camera live or show the video ...      1              2
# 7864  Love the cameras but the apps (iOS, Android an...      3              0
# 7865  Something is seriously wrong with this app. My...      1              2
# 7866  Constantly have trouble conecting to cameras, ...      2              1
# 7867  Only reason I say 2 stars is I'm constantly ha...      2              7
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                  1.41.1 2020-04-24 01:23:50         None       NaT
# 1                  1.41.1 2020-04-20 19:31:08         None       NaT
# 2                  1.41.1 2020-04-22 13:50:04         None       NaT
# 3                  1.40.1 2020-04-16 20:31:19         None       NaT
# 4                  1.41.1 2020-04-20 00:03:48         None       NaT
# ...                   ...                 ...          ...       ...
# 7863           2.15_27085 2020-04-28 02:05:10         None       NaT
# 7864           2.15_27085 2020-04-22 03:45:01         None       NaT
# 7865           2.15_27085 2020-04-25 07:13:38         None       NaT
# 7866           2.15_27085 2020-04-28 15:31:46         None       NaT
# 7867         2.14.0_27056 2020-04-05 15:32:08         None       NaT
#
#                        appId
# 0     com.herzick.houseparty
# 1     com.herzick.houseparty
# 2     com.herzick.houseparty
# 3     com.herzick.houseparty
# 4     com.herzick.houseparty
# ...                      ...
# 7863            com.arlo.app
# 7864            com.arlo.app
# 7865            com.arlo.app
# 7866            com.arlo.app
# 7867            com.arlo.app
#
# [7868 rows x 10 columns]

# %%
#drop stuff you don't need 

del df['userImage']
del df['reviewCreatedVersion']
del df['repliedAt']
del df['replyContent']
del df['userName']
del df["thumbsUpCount"]
del df["at"]

# %%
df
# Out:
#                                                 content  score  \
# 0     It's a good app, when it works! I've had House...      3
# 1     This app is pretty smooth when it comes to vid...      3
# 2     Not the best features. It is very flimsy with ...      2
# 3     Great. Very reminiscent of Skype on computers ...      4
# 4     Certain parts of this are great, the concept a...      3
# ...                                                 ...    ...
# 7863  Wont stream the camera live or show the video ...      1
# 7864  Love the cameras but the apps (iOS, Android an...      3
# 7865  Something is seriously wrong with this app. My...      1
# 7866  Constantly have trouble conecting to cameras, ...      2
# 7867  Only reason I say 2 stars is I'm constantly ha...      2
#
#                        appId
# 0     com.herzick.houseparty
# 1     com.herzick.houseparty
# 2     com.herzick.houseparty
# 3     com.herzick.houseparty
# 4     com.herzick.houseparty
# ...                      ...
# 7863            com.arlo.app
# 7864            com.arlo.app
# 7865            com.arlo.app
# 7866            com.arlo.app
# 7867            com.arlo.app
#
# [7868 rows x 3 columns]

# %%
df.head()
# Out:
#                                              content  score  \
# 0  It's a good app, when it works! I've had House...      3
# 1  This app is pretty smooth when it comes to vid...      3
# 2  Not the best features. It is very flimsy with ...      2
# 3  Great. Very reminiscent of Skype on computers ...      4
# 4  Certain parts of this are great, the concept a...      3
#
#                     appId
# 0  com.herzick.houseparty
# 1  com.herzick.houseparty
# 2  com.herzick.houseparty
# 3  com.herzick.houseparty
# 4  com.herzick.houseparty

# %%
y = df["score"]
X = df.drop("score",axis =1,inplace=False)

# %%
#X_train,X_test,y_train,y_test = train_test_split(X.index,y,test_size=0.2)
df_train=pd.concat([X,y],axis=1).iloc[X_train] # return dataframe train
df_test=pd.concat([X,y],axis=1).iloc[X_test] # return dataframe test
print(df_train.shape, df_test.shape)
# Out:
# (6294, 3) (1574, 3)

# %%
df_test
# Out:
#                                                 content  \
# 4901  Easy to navigate. Makes it easy to maintain se...
# 749   I don't kwn what is wrong with my hangouts it'...
# 5841  I do not think this is an effective tool. It's...
# 4044  D O N T U S E S P I R I T I've been trying for...
# 1650  I like the game and it's sound affects also to...
# ...                                                 ...
# 5898  Was quite impressed with this app. Not the eas...
# 2115  Overall the app is excellent - The workout ses...
# 2992  In general I am fan of workout in home and I a...
# 7686  So for the first time since the Pan Cam's rele...
# 2290  Came here from the "MapMyRun" app and will not...
#
#                                                 appId  score
# 4901                            com.brighthouse.mybhn      5
# 749                           com.google.android.talk      4
# 5841                                    com.remind101      1
# 4044                           com.spirit.customerapp      2
# 1650                       com.playgendary.creamaster      4
# ...                                               ...    ...
# 5898                            com.classdojo.android      2
# 2115                                     com.nike.ntc      4
# 2992  net.beginners.weight.loss.workout.women.yoga.go      4
# 7686                                       com.hualai      5
# 2290                                 com.nike.plusgps      5
#
# [1574 rows x 3 columns]

# %%
from sklearn.pipeline import Pipeline
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize  
from sklearn.feature_extraction.text import TfidfVectorizer ,TfidfTransformer,CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV, KFold
import nltk

# %%
text_train=df_train["content"].values
text_test = df_test["content"].values
y_train= df_train["score"].values

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\SAITEJA-
# [nltk_data]     WORKMACHINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\SAITEJA-
# [nltk_data]     WORKMACHINE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\SAITEJA-
# [nltk_data]     WORKMACHINE\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %%
stemmer = SnowballStemmer("english", ignore_stopwords=True)

# %%
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: ([stemmer.stem(w) for w in analyzer(doc)])

# %%
stemed_vec = StemmedCountVectorizer(min_df= 2,ngram_range=(1,2),tokenizer = LemmaTokenizer())

# %%
clf = Pipeline([("vec",stemed_vec),("tf-idf",TfidfTransformer()),
	            ("SVD",TruncatedSVD(n_components=3000)),("svr",SVR(C=10,gamma=1,verbose=1))])

# %%
param_grid = {'svr__C': [0.001, 0.01, 0.1, 1, 10], 'svr__gamma': [0.001, 0.01, 0.1, 1],
              'SVD__n_components':[1000,2000,3000,4000],'vec_ngram_range':[(1,1),(1,2),(1,3)],
              'tfidf__use_idf': (True, False)}

# %%
cv = KFold(shuffle=True)
grid = GridSearchCV(clf, param_grid=param_grid, cv=cv, verbose=3)

# %%
clf.fit(text_train, y_train)

# %%
y_test = clf.predict(text_test)
print(y_test)
# Out:
# [4.70221197 3.6223439  4.53085249 ... 5.27883477 3.3552826  3.61733449]

# %%
#Adjust the value to 1~5
for i in range(len(y_test)):
	if (y_test[i]>5) : y_test[i]=5
	if (y_test[i]<1) : y_test[i]=1

# %%
#tbd storing and organizing results comparing with ios model
#result=[]
#for i in range(df_test.shape[0]):
#    result.append([df_test["appId"][i], y_test[i]])
#result_df = pd.DataFrame(result)
#result_df.to_csv("result_df.csv", index = False, header = False)

# %%
df_test
# Out:
#                                                 content  \
# 4901  Easy to navigate. Makes it easy to maintain se...
# 749   I don't kwn what is wrong with my hangouts it'...
# 5841  I do not think this is an effective tool. It's...
# 4044  D O N T U S E S P I R I T I've been trying for...
# 1650  I like the game and it's sound affects also to...
# ...                                                 ...
# 5898  Was quite impressed with this app. Not the eas...
# 2115  Overall the app is excellent - The workout ses...
# 2992  In general I am fan of workout in home and I a...
# 7686  So for the first time since the Pan Cam's rele...
# 2290  Came here from the "MapMyRun" app and will not...
#
#                                                 appId  score
# 4901                            com.brighthouse.mybhn      5
# 749                           com.google.android.talk      4
# 5841                                    com.remind101      1
# 4044                           com.spirit.customerapp      2
# 1650                       com.playgendary.creamaster      4
# ...                                               ...    ...
# 5898                            com.classdojo.android      2
# 2115                                     com.nike.ntc      4
# 2992  net.beginners.weight.loss.workout.women.yoga.go      4
# 7686                                       com.hualai      5
# 2290                                 com.nike.plusgps      5
#
# [1574 rows x 3 columns]

# %%
type(text_test)
# Out:
# numpy.ndarray

# %%
text_test[:2]
# Out:
# array(['Easy to navigate. Makes it easy to maintain services with Spectrum.',
#        "I don't kwn what is wrong with my hangouts it's not working at all like whenever I'm trying to video call on the hangouts my phone shuts and I can't share anything like photos, gifs, video etc., It's just stuck at uploading that's it. What is going on can anybody explain me plz fix it. I love hangouts very much and I don't want to stop using it. Thanks."],
#       dtype=object)

# %%
y_test = clf.predict(text_test[:2])
print(y_test)
# Out:
# [4.70221197 3.6223439 ]

# %%
#always do this 
for i in range(len(y_test)):
	if (y_test[i]>5) : y_test[i]=5
	if (y_test[i]<1) : y_test[i]=1

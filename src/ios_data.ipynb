# %%
import pandas as pd
import ast
import json
import re
from itertools import chain

# %%
try:
    with open('./data/sample_review.txt', 'r') as data_file:
        data = data_file.read()
except IOError:
    print('Error while opening App\'s ID file. make sure that\
    you have a file named "appsid" in the irectory of this\
    scrip and you have right permissions to access file. \nExiting...')

print(data)
# Out:
# [ { id: '5675067217',
#     userName: 'bling.blazer',
#     userUrl: 'https://itunes.apple.com/us/reviews/id948229368',
#     version: '1.34.1',
#     score: 4,
#     title: 'Unique and helpful😀',
#     text: 'I downloaded houseparty maybe two years ago and one of the great things about it is you get the chance to talk to people you wouldn’t usually talk to or call on purpose and you make a lot of new friends this way. One of my best friends to this day I would’ve never thought of talking to if it hadn’t been for houseparty. It’s a great app overall the only reason it lost that star was because of what it did with streaks. It started off cool like you and your friends would try to rack up minutes and because it was every five days in circumstances where they couldn’t be on house party I felt it was a good amount of time to give. But then they began decreasing it to three and then two days which means you basically have to be on the app everyday in order to keep your minutes or streak or whatever. It’s not really the fact that minutes and aesthetic were lost but more of the passive aggressive way to keep people on the app. Minutes were one out of many of my motivations to go back to the app knowing i had a good amount of time, but now there’s no motivation if you’re just going to lose them every two days. But overall it is still a very good app and helpful in making new friends',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3983990620',
#     userName: 'kittyawsomness',
#     userUrl: 'https://itunes.apple.com/us/reviews/id851361615',
#     version: '1.30.0',
#     score: 5,
#     title: 'Great app!!',
#     text: 'I think that Houseparty is an amazing app. It allows you to video chat with more than one of your friends easily. You can message your friends through the app, which I find very convenient. Speaking of friends, on the app somebody has to request to be your friend, so thistles the app slightly more private then it already is. The quality of the video is very good. Houseparty has the same qualities as the app “FaceTime” and more. You can play games with your friend that the app serves to you while on a call with your friend. You can make group conversations on the messaging part of the app. And to wrap it up, you can call other friends that are on the app, from the app, and you can also just do an audio call. There are many more great things about housparty that I can’t fit into one review. So I definitely recommend this app for any age group. (It is not at all inappropriate or to mature for anyone that is able to use “FaceTime” or “Messages”). The app is very accommodating!!! And awesome!!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3313881039',
#     userName: 'Syd Glitter',
#     userUrl: 'https://itunes.apple.com/us/reviews/id877470093',
#     version: '1.20.0',
#     score: 5,
#     title: 'Love it! ❤️',
#     text: 'First of all, I don’t know why people are complaining? Ok, I have lots of friends that don’t have phones and I can’t talk to them, but with Houseparty I can! Sometimes I want to video chat with multiple people at the same time but I can’t do that with FaceTime. I can with Houseparty! There are little things here in there but I love this app! One time these two people would not stop calling me and anytime I would come on they would join me, but you can sneak onto Houseparty. See, anytime you go onto the app your friends get a notification, but there is a way to sneak on, so your friends don’t get a notification. Also, they give you really cool facts on the home screen, one time I spent hours just looking at the facts! Lastly, if you don’t like getting notifications every time one of your friends comes on, there is a way to do turn it off. Overall, I love this app and I don’t know why more people are using this app. It’s a great app to download and I recommend this app to anyone!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2741757283',
#     userName: 'ZandriaDavis3',
#     userUrl: 'https://itunes.apple.com/us/reviews/id309993400',
#     version: '1.11.5',
#     score: 4,
#     title: 'More than an app',
#     text: 'I know this app is supposed to be about fun and seeing a lot of people at one time. But I want the developers to know that you gave my family something that is truly irreplaceable. My uncle got sick suddenly and was placed in the hospital on ICU. I have a HUGE family and a lot of us are spread apart in different states. Houseparty allowed us who couldn’t be there physically to be there virtually during precious moments. We were able to say our last goodbyes, hear funny stories, comfort one another, and be there for his final breath. Death is not fun but this app was one piece of making it a little more bearable because we were literally able to be there for one another. Even on different time zones, doing different things, we were all there. That is something that we are all thankful for and will never forget. We literally said to each other how perfect it was that we found this app and got everyone connected a month ago, not even knowing that it would be a necessity during this tragic time. So thank you.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5809025142',
#     userName: 'JaiDJade',
#     userUrl: 'https://itunes.apple.com/us/reviews/id146345016',
#     version: '1.40.3',
#     score: 2,
#     title: 'pretty bad',
#     text: 'it’s alright when it works but it doesn’t even come close to comparing to Zoom, Duo, FaceTime, etc. with AirPods, the latency is so bad that you would hear a response until at least 2 full seconds have passed. the quality leaves much to be desired. the was frequent feedback on the call, meaning that it has issues with noise-cancellation (which other video calling apps have no issues with). it’s inefficient and drains my battery like no other. the video quality honestly was pretty good but the voice quality was subpar. an hour into the call we got kicked and couldn’t join each other again. we spent 30mins trying to call them and them calling me and we’d select “join” but our efforts were futile because it never worked. eventually we just gave up. not to sound like a Karen with the hard R but i’m so disappointed in this app. i ended up deleting it after the first use. also, part of me thinks that privacy isn’t at all a concern of theirs (i should read the privacy policy yes i know) so i’m even afraid that having the app installed is going to lead to me getting hacked and locked out of my accounts',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5850558430',
#     userName: 'Giojuakin_29',
#     userUrl: 'https://itunes.apple.com/us/reviews/id529483637',
#     version: '1.41.1',
#     score: 1,
#     title: 'Annoyed',
#     text: 'This app is was good... I constantly have to be erasing and downloading this app for it to function and everytime I do it it doesn’t pass a day and it’s start again with its glitches, bugs... everytime someone enters or leaves a group it freezes, to a point where I have to get out the app. There’s no point of having the “minutes countdown of talking” if its been eliminating and now you can’t FaceTime sceeen share. Plus when it use to do screen sharing it used to kick me out the app. I always have good Wi͏f͏i and signal and it stills do its glitches. Like I only have it cause I find it good to socialize but when it come to the features, y’all need to fix. Why give promotion to this app if it crashes a lot. Sometimes the audio doesn’t even work, battery drains in minutes and obviously it’s slow. This app also effects other apps to be honest. Other social app similar work better. Sorry, but the truth is that years ago this app was much better than now. If y’all can’t fix the app there’s no point of giving it promotion or making people download it. Due to all those reasons I give one star, if it’s for me zero stars. \n\nTHIS APP NEEDS TO BE FIX AND WE ALL KNOW THIS!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5726366676',
#     userName: 'im.belle',
#     userUrl: 'https://itunes.apple.com/us/reviews/id87245783',
#     version: '1.34.1',
#     score: 3,
#     title: 'Fun app, but lags',
#     text: 'My friends and I were mid playing last night at around 12 am when the app crashed. It started to lag on all ends and we couldn’t even try to video chat with each other because we weren’t showing up on our personal friend list even though we were all waiting for each other the whole time. It wasn’t loading. My friend uninstalled and reinstalled and no changes happened. It started to work 30-40 minutes later. We were all annoyed and wondering what was happening.\n\nAlso, in the games, cards and words constantly repeat which looses excitement in the game. We all kept saying “wait! We just did this!” And as for the Karaoke Night, they were all older songs that majority barely knew. We were expecting more current songs from 90s - current times. It seemed to be opposite. \n\nThis game is definitely bringing people together especially during this quarantine, but it definitely needs some improvement. I was trying to find the “help” section to see what I can do, but couldn’t. Let time heal itself.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4445698270',
#     userName: 'TheReviewingCorgi',
#     userUrl: 'https://itunes.apple.com/us/reviews/id684281495',
#     version: '1.34.0',
#     score: 4,
#     title: 'Amazing! Just one thing..',
#     text: 'House party is a great way to hang out with ALL of your friends at any time! I’d call for hours, and we always have great connection wherever we are. The games are great- my friend group loves the game Chips and Guac! We played forever, and our answers always made us laugh. However, I do find one thing that may be useful for some. In some situations, you want to call but can’t because you have to be quiet at night or while someone’s working. I’ve had to decline calling my friends because of this. I think that adding a chat to be available (when needed) on the side of the screen would be helpful to people like me!! Then, we’d be able to chat without others hearing us. I’d be simple for the others to see, and reply to. We could have headphones in listening to our other friend(s) and still be a part of the conversation, all while nobody knows! I know this is just one review and nobody else has asked, but I would really enjoy it! Thank you for your time!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4574857919',
#     userName: 'hsshsjsjaiajzs',
#     userUrl: 'https://itunes.apple.com/us/reviews/id787735740',
#     version: '1.34.1',
#     score: 4,
#     title: 'Best Friends',
#     text: 'I love the app and use it a lot to chat and socialize with buddies. The only problem/suggestion is with the whole "Best Friends" system and how that all works. I understand that "best friends" are gained onto your profile based off of how much time you speak to specific people, but i also believe that best friends should also be gained by if you pass a lot of notes/ texts to a specific person on the app. Because alot of times i cant physically cant speak🗣 to someone over the app whether its because im on lunch break at training or im at a family event, or im at a loud place, etc. which is why i use the "Pass A Note" feature, and i would like to gain best friends over that feature too. I talked to my friends about the suggestion and they all agreed and said they had the same exact thought. I REALLY FEEL that u should add this to the app because it will help it grow and change my 4 star rating to a 5 star rating. Pls reas this and make it happen, us users will love it.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4267193584',
#     userName: '93729201',
#     userUrl: 'https://itunes.apple.com/us/reviews/id649534339',
#     version: '1.33.1',
#     score: 5,
#     title: 'AMAZING ❤️ APP 😍😃',
#     text: 'This app is very good. You can talk to all your friends and have a good time. Other reviews said that like it was the worst app ever because it had to use internet, well first of all you can’t connect ANY video chat without WiFi same with calling\nYou can’t call without WiFi so that was a pretty dumb one but yeah. It’s a rlly good app. You can play games with people, message them, learn cool facts, and more. I moved a couple of years ago and I moved 12 long hours away from my 5year old cousin. I have an iPod and his mom has a Samsung. I can’t FaceTime them because I have an iPod touch and it won’t work. So we got this app and now we can talk to eachother and we won\'t be so far away from each other. He is deaf so he can’t hear so we can audio call and he loves to show me his new toys and cats on the Houseparty video chat. I would really recommend you trying this app. You might have a wonderful time.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5846543532',
#     userName: 'mentally dating Corey Seager',
#     userUrl: 'https://itunes.apple.com/us/reviews/id1073633028',
#     version: '1.41.1',
#     score: 4,
#     title: 'love it, but too much spam',
#     text: 'OK, I love this app. It’s awesome. I’ve never had a serious problem with bugs or glitches. The one thing I would recommend working on is the notifications. \n     It gets annoying when the app thinks I didn’t see the last four “in the house” notifications for one person. I’ve had times when one of my friends is on a call with some other people and my phone tells me ten times that that person is on the app. Thank you, but I saw it the first time. \n     Also because of the spam notifications, most of my friends have turned them off, so I have a hard time trying to add friends or invite them to calls. This isn’t their fault, but it’s frustrating. \n     This is a great app, but please try to fix it so it doesn’t tell me “they’re in the house! they’re in the house! you moron, LOOK!” It’s very annoying. Other than that, I think it’s absolutely fantastic and I will use it for a very long time.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3969924763',
#     userName: 'Kitty Gaming YT',
#     userUrl: 'https://itunes.apple.com/us/reviews/id567319607',
#     version: '1.30.0',
#     score: 3,
#     title: 'A GLITCH',
#     text: 'I got Houseparty to talk to my many friends at the same time because some didn’t have an Apple device. It worked for all of them perfectly fine (i think),but it had an annoying glitch for me. Whenever I went in a chat room or just called one person, it had some kind of echo that wouldn’t allow me to hear my friend(s) in the chat room. I have two electronic devices. An Ipod and an Ipad. I downloaded this app on both devices just in case my ipod died viceversa. But this glitch was effective to BOTH MY DEVICES. At that point, I gave up. I thought it was my wifi or something else. I tried going in EVERY SINGLE ROOM IN MY HOUSE. Still didn’t work. So I decided to use a different app to talk to my friends. This app is WONDERFUL and it has connected many people who live far away from each other, but it just didn’t work for me. I would LOVE to use this app again, but my electronics or the app won’t permit me with that glitch. This is the ONLY reason why I gave this a 3-star review. \n\n- A Friendly Reviewer 🤗',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2874468314',
#     userName: 'Hwvbdxb',
#     userUrl: 'https://itunes.apple.com/us/reviews/id320507291',
#     version: '1.12.5',
#     score: 3,
#     title: 'Three stars review explanation',
#     text: 'So, I gave Houseparty a 3star review because they were always sending me notifications to sign up with Facebook. I’m to young for Facebook and I don’t like it. Making something do something they don’t want to is not appropriate. Second, it doesn’t work if you don’t have WiFi........? what if you want to talk with your family members as a group in one chat and you can’t because you don’t have WiFi. It’s very annoying how apps don’t let you play or do things on it without WiFi. It’s very annoying, and for me growing up with not that much WiFi in my household, it really annoys me of how I always have to have it. Third, the app will also don’t work if you have slow WiFi. What I meant with growing up with not that much WiFi in my household, I meant it was very slow. Sure now it fast but still. What about other people. They just want to enjoy their time. Not from worrying if their WiFi is bad. So this is my opinion. I am only 11 years old and I still have my judgments.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5643740516',
#     userName: 'Notyetgoldenoldie',
#     userUrl: 'https://itunes.apple.com/us/reviews/id14069909',
#     version: '1.34.1',
#     score: 5,
#     title: 'LOVE IT',
#     text: 'I use this app almost everyday to chat with my friends. It has great privacy settings. I can sneak into the house, and I can also turn on a setting where it locks the room that I’m in automatically. I love the feature where you can see who is online or around, and I love the games. The only improvement that I might give them is the Wi-Fi settings. Maybe it is just me and my friends not having good Wi-Fi, but it is usually a little lag. Overall a great app and I will readI can sneak into the house, and I can also turn on a setting where it locks the room that I’m in automatically. I love the feature where you can see who is online or around, and I love the games. The only improvement that I might give them is the Wi-Fi settings. Maybe it is just me and my friends, but it is usually a little bit lag he. Overall I will write this app five stars. ⭐️ ⭐️ ⭐️ ⭐️ ⭐️',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5575018882',
#     userName: '💛🌼💛',
#     userUrl: 'https://itunes.apple.com/us/reviews/id475221027',
#     version: '1.34.1',
#     score: 5,
#     title: 'AHH BEST APP EVER (but only few problems)',
#     text: 'I like this app coz it’s rlly easy to call ur friends and it tells u when their online but the only thing I don’t rlly like is u can only add 15 ppl to one group and the name is only 25 words for a group. Also when it says someone is around they actually aren’t on their device at all so when ur calling someone and then u say u gotta go somewhere they think u don’t wanna talk to them which seems really unfair. Also delete messages \n\nBut why it’s good coz it’s rlly safe and it’s fun to use and plus there isn’t any bills for calls. If ur parents don’t let u show them this review: PARENTS PAY ATTENTION: \nThis app is sooo safe coz u have to accept requests of friends and Houseparty is also good if u wanna have study sessions of something together but u can’t actually meet up or if u have lessons with a tutor but he/she can’t come u can do it over house party so yeah HOUSEPARTY IS AWESOME',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5761944974',
#     userName: 'iSo80s',
#     userUrl: 'https://itunes.apple.com/us/reviews/id86764732',
#     version: '1.34.6',
#     score: 4,
#     title: 'Great way to stay connected but can always use improvement.',
#     text: 'I really like this app. It’s helped me stay connected with friends and family during the current shelter in place we’re all experiencing. One issue I have is that if someone wants to join in to video chat with you, the app doesn’t ask permission if your screen is open. It automatically just begins a video chat session and that could be awkward at times. I was in the middle of brushing my teeth and the screen just popped on bc I’d opened it to see who was online. I really feel like there should be a delay where permission is asked and either granted or denied. It shouldn’t just open up into a chat like that. It’s a bit weird. Other than that and occasional connection issues (could cry well just be my internet), I’ve had no problem at all with Houseparty. It’s an amazing way to have fun with friends when physical connection isn’t possible.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5740699899',
#     userName: 'hdbdudneb',
#     userUrl: 'https://itunes.apple.com/us/reviews/id1141966101',
#     version: '1.34.5',
#     score: 4,
#     title: 'Great just one thing',
#     text: 'I love this app so much but there’s just one main flaw for me. The thing I don’t like about this app is that when your using the app any of your friends can instantly connect to you there’s no answer or decline button. This problem only happens when I’m on the app other times when playing another game and someone calls me I can choose to answer. I’ve had situations where a friend would call me and my parents would be on a work call and I didn’t have my headphones in. My dad would have to come and ask me to keep it down. So I had to go up in my room, and sometimes I didn’t even want to be on the phone, but I didn’t want to be rude. There was also this time where, I was checking my friend requests while getting dressed and a friend called me. I had no pants on so I had to ask to call her back. Other than that I love this app! Please fix this problem with a new update.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2808957809',
#     userName: 'sophie10566',
#     userUrl: 'https://itunes.apple.com/us/reviews/id512742454',
#     version: '1.12.0',
#     score: 3,
#     title: 'Please make the mackbook Houseparty better',
#     text: 'I have already made a review on house party on asking you to give us house party on the MacBook and I’m so happy you did but in my opinion it needs some help. For example my Houseparty and my friends Houseparty on the MacBook is really bad, for one of my friends so bad that she can’t even open it. Another thing it’s not even an app that you can download on the App Store it’s a link that you can send to your email, but the thing is what happens if you don’t have an email, you have to think about these things because some people in Houseparty are little and they just want to talk to their friends. Also there is no way to log out on your Mac to switch to other accounts and on top of that you can’t invite anyone to rooms, receive messages, and send messages. These are all the things I ask to make it better. \n\nPs: my friend also sent a review for filters and you said they were gonna come out soon but I still see no sight of that.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2212385997',
#     userName: 'Ok man34',
#     userUrl: 'https://itunes.apple.com/us/reviews/id185222351',
#     version: '1.6.0',
#     score: 3,
#     title: 'Please Fix',
#     text: 'While this is a great app, there are some issues that have yet to be fixed. first of all, it constantly kicks people out of the app. that can get annoying when you are trying to have a conversation with someone and it does this several times throughout. Another being that the audio is sometimes awful to the point where you cannot hear what the person is saying. It cuts out at random points throughout and it gets hard to understand. It also takes a long time to load. I am currently trying to use the app and it refuses to load. It has nothing to do with my connection as this happens no matter where I am or what wifi I am using. The app gets updated a lot but it doesn\'t seem to actually be fixing anything. I would love to give this app a five star review but because there’s so many bugs I can’t. I make sure to always update the app when updates are available, but nothing seems to change or improve.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3970250407',
#     userName: 'I LOVE swim 💜💜💜',
#     userUrl: 'https://itunes.apple.com/us/reviews/id889124068',
#     version: '1.30.0',
#     score: 4,
#     title: 'I have some questions',
#     text: 'Hi! I like this app very much. It helps my friends and I communicate. One of my friends have Samsung and I have an iPad so I could never talk to but her but now I can! I just have a few questions. How do you sneak into the app? I have a few friends on this app, that anytime I go on the app they join me. Not that I don’t love my friends or anything, it can just get annoying sometimes. I have looked in house rules and it tells me to pull down the notification but what notification?! Also how do you make a face mail? When I try to it says turn device around to record. So I do that and nothing happens and sometimes it is very important. One time I couldn’t reach one of my friends because she wasn’t on her phone. It would be helpful if you put how to make a face mail in the House rules. Otherwise then those two questions I love the app and would definitely recommend it!👍💜',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5854451526',
#     userName: 'CodeMonitor',
#     userUrl: 'https://itunes.apple.com/us/reviews/id414307008',
#     version: '1.41.1',
#     score: 5,
#     title: 'Even worked in ICU',
#     text: 'Thanks sooo much for this app!  I’ve been able to use this with my 3 sisters, and also with friends in place of our regular dinner outing.   I had never tried it with more than 4 until today.  One of my best friend’s has been COVID-19 positive for over a month now and has been in ICU for a month, and was on ventilator 11 or more days.  The app did great with seven of us in 4 states being able to see our friend or relative in the ICU, and he us.\n\nThe hospital chaplain had to get phone from parking lot, walk it in & up elevator to ICU.  Nurse put on PPE, and took phone into ICU. A few “freezes” due to connection strength, but it never cut out.\n\nMy friend cannot talk again yet, but could move his eyes & arms in response to us talking & waving.  We could all tell this meant so very much to him & lifted his spirits, so again, thank you so very very much !!!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3554024480',
#     userName: 'SCANIAPPLE',
#     userUrl: 'https://itunes.apple.com/us/reviews/id379285671',
#     version: '1.24.0',
#     score: 5,
#     title: 'Best app ever!!!!',
#     text: 'Houseparty is the best thing that ever happened to my life because there’s no other app like it I mean there is the new iPhone update and it includes Group FaceTime but when my friends start off there the say let’s just go to Houseparty. I also love the feature where you have mutual  friends because people that I have not seen for at least 2 years have Houseparty and I can call them. I use this app every single day with my friends and even my family. I also love the new logo it’s more stylish and fun then just a cup. I am so happy that Houseparty is an app and I hope all of you working at Houseparty HQ are working on making it better. Oh and I forgot to say something about face mail, ITS THE SMARTEST THING EVER! Whoever designed that should get a reward.\n\nThank You for reading my review and I hope to hear back from you guys at Houseparty!\n\nByeeeeeeee! 👋',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5827450304',
#     userName: 'Tigervibes94',
#     userUrl: 'https://itunes.apple.com/us/reviews/id108410000',
#     version: '1.41.0',
#     score: 3,
#     title: 'Fun App but some annoying notifications',
#     text: 'This app is so great. My friends, family, and coworkers have loved using this as opposed to FaceTime or zoom because of the games. The games with your loved ones on this really helps to temporarily forget the stressful times we have living in. However, there are some really annoying aspects of this app. 1) Way. Too. Many. Notifications. The notifications settings in the app are very limited. I get a notification every time a new Facebook friend joins the app. It’s extremely annoying. I’m probably going into my iPhone settings and completely disable notifications for the app entirely until the fix it. 2) the app isn’t intuitive and user friendly. Even for me who is super techie, it’s a trial and error of pushing buttons to navigate around. My older relatives would definitely not be able to figure this out alone. The user experience should be improved a bit.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2193606655',
#     userName: 'Scarsdale surprise',
#     userUrl: 'https://itunes.apple.com/us/reviews/id460737568',
#     version: '1.5.23',
#     score: 4,
#     title: 'Likeable but has a few issues.',
#     text: 'I absolutely love this app! I was psyched when my friend showed it to me! I like that you can wave to people and alert them that you are in the app and that the app tells you when someone you don’t know is in a room. I also think it’s a nice touch that you can lock rooms, but I hate hurting my friends feeling if I want a private chat with a couple of other people with out them. I hope that in the future their can be more privacy settings. But over all this is he best video chatting app I have ever tried. But I’m tired of whenever I go to the app someone can join. I clicked the app on accident and my friend (a boy) logged on when I had only a towel on. I ended the video chat before he could even connect but that was very scary! So I hope it can be changed for the future, but anyway a great app and I hope it gets lots of praise😇',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2045250689',
#     userName: 'Concened Parent',
#     userUrl: 'https://itunes.apple.com/us/reviews/id429333546',
#     version: '1.5.10',
#     score: 2,
#     title: 'Honestly questioning this app...',
#     text: 'This app has been great, it’s as advertised. It allows you to chat with many different people, doesn’t crash and is hardly glitchy. My concern is after having this app for a month or so, I am beginning to question the privacy given on this app. If you continuously tap the facts, it shows new ones every time but there are however some very inappropriate almost “facts” such as- “You look hot”, and many other gender assuming “facts” and is leading me to question if there are people behind this app watching you and putting in obvious information in specific people. Such as if the user is a male, they give you facts specifically for males or if you are a female, it gives you facts specifically for females. I have been given many inappropriate facts and just facts in general that aren’t appropriate for children even though this app is advertised for 9+. Definitely gonna be looking into this because it puts in a very unsafe and uncomfortable position.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5015805462',
#     userName: 'Cheech64',
#     userUrl: 'https://itunes.apple.com/us/reviews/id28751609',
#     version: '1.34.1',
#     score: 1,
#     title: 'Doesn’t work well anymore on iOS 13',
#     text: 'Doesn’t work anymore on iOS 13. Always drained your battery too much anyways. On to the next app!\n\nWhile I think this app is loads better than FaceTime (doesn’t hang up when you turn off your screen, takes up all your screen with no wasted black space,) it keeps messing up the orientation of video chats as my friends will be upside down or sideways when chatting. It requires closing the app and reopening it. Also, I wish there weren’t so many gestures, as everyone always accidentally swipes out of a room. It’s a feature none of us use (why would we be going in and out of chats like that?) And if you guys could tone it down with the amount of notifications this app produces, that would be great. Other than that this app is still way better than FaceTime, which has become gimmicky junk over the years. All we want to do is video chat to talk, no stupid overlays or memojis that only drain the iPhone even more and add no functional value to the experience.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3074325029',
#     userName: 'Sugurray',
#     userUrl: 'https://itunes.apple.com/us/reviews/id700959888',
#     version: '1.15.0',
#     score: 4,
#     title: 'Great app but needs improvement',
#     text: 'I love this app! It is so great to be able to talk to all of my friends at one time but it needs improvement. It glitches all the time and the sound is always cutting in and out. There was time when me and my friend were having a serious conversation and because the sound cut in and out I missed important parts of the conversation. I also think there could be improvements on the whole “passing notes” agenda! One of my friends doesn’t have a working phone and so Houseparty is the only way we stay in touch. Sometimes we can’t video chat and we want to text but sometimes we don’t receive the notes or it freezes before we can pass them, so I also think there should be improvements there. This app is great but it could be even better if it had these improvements😊!!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5732461091',
#     userName: 'Cassie Norton',
#     userUrl: 'https://itunes.apple.com/us/reviews/id140766515',
#     version: '1.34.1',
#     score: 5,
#     title: 'Love so far but wish there were more games',
#     text: 'I downloaded this app a few days ago and I absolutely love it. Especially now with the quarantine it makes it easier to be able to chat with everyone. A lot of people I know don’t have iPhones so we can’t FaceTime. This app solves that problem. The other problem with FaceTime is you can only talk to one person at once. I LOVE that you can talk to multiple people at once. I had a group of 6 the other day and it was great to almost feel like we were all together again. The ONLY thing I wish was different was that there were more games. There are a few now but I hope there would be a few more and better variety in the future. There’s also a LOT of repeat questions on trivia and drawing guesses etc.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5396120669',
#     userName: 'KittyCatCruiser',
#     userUrl: 'https://itunes.apple.com/us/reviews/id722517075',
#     version: '1.34.1',
#     score: 4,
#     title: 'Pretty good app',
#     text: 'I absolutely love Houseparty. The only change I wish was real was to make it less glitchy. The glitching just drives me CRAZY! The other change is that when it says “no one can hear you! Our bad!” is really annoying. I feel that there is no purpose for it. If it’s ur bad then fix it! I don’t even know why they mention it. \n🤷‍♀️🤷‍♀️🤷‍♀️?! \n\nOtherwise, this app is by far one of the BEST apps I’ve tried out. In my opinion, it is a lot better than FaceTime. The coolest features are the games, and that u can have friends u could talk to on a daily bases. The games r such an awesome idea if u don’t just wanna talk, but you wanna play, too! And when I play trivia, I start to learn new things!!! Like how drakes real name is Aubrey! That was an unexpected fact. Overall, this is by far, the best video chatting app.👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2885521529',
#     userName: 'NickiMinaj666',
#     userUrl: 'https://itunes.apple.com/us/reviews/id700381477',
#     version: '1.13.1',
#     score: 3,
#     title: 'I mean',
#     text: '#1. It’s not the worst but it’s not the best. I like that I can face time my only 2 friends at one time, but one time I went to the bathroom and I went to lay back down. I looked at my phone and saw that I was on Houseparty with my friend. Please make it that if your friend wants to talk to you, you have to click like an answer button or something. I could have been doing something else when this happened!!\n\n#2. I was reading a review and it said that Houseparty helped the reviewer and his/her loved one be together for the loved ones last breath. Now this is the review that got it up to 3 stars! But then when I read the developers response, I was shocked! He/She said “This review was very heartwarming. How can we get it up to 5 stars!!!!! I mean I know you wan your app to have 5 star reviews from everyone but that’s not gonna happen my friend!!!! This knocked it down to 1 star........ unbelievable......',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5733172668',
#     userName: 'suppp17',
#     userUrl: 'https://itunes.apple.com/us/reviews/id1150965158',
#     version: '1.34.1',
#     score: 3,
#     title: 'Big fan of the app but a slight issue arose',
#     text: 'Big fan of the app as I am able to reconnect with friends and family I haven’t spoken to in a long time. All the games are also a big plus. \n\nIssue: There should be a choice to be able to either be accepted or denied in joining a chat, rather than automatically being put into one when someone randomly decides they want to join you. \nI have friends that had joined into a chat no one knew them in except for me and it just made things uncomfortable, especially when it happened mid game. People could also be in the middle of a personal conversation and a random friend or family member could just join in and make things weird. If possible, maybe a choice to be able to kick someone out of the group chat would be helpful. Or maybe being able to ghost yourself while on the app.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4280126343',
#     userName: 'Jyoti dee',
#     userUrl: 'https://itunes.apple.com/us/reviews/id551349165',
#     version: '1.33.1',
#     score: 5,
#     title: 'The best way to connect. Download NOW!',
#     text: 'Recently, summer break came and I transferred to a new school. Because of Houseparty, I’m able to connect with my friends while I’m away! The games always make us laugh and I feel we are connecting even more! One time, my friend, (fake name: Pablo) was spamming my call button. I kept hanging up and after like a million attempts, Pablo stopped and I answered and he started yelling at me. My other friends got the in the house notifications and joined. Then we all started arguing and joking at the same time. Chips and Guac was our favorite. For the dead emoji I put a dead meme or old celebrity and the judge started laughing. Keep up the epic updates and soon, houseparty will grow to be an extremely famous app. Thanks for the best app ever!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2447178604',
#     userName: 'uniclrn lady',
#     userUrl: 'https://itunes.apple.com/us/reviews/id610658668',
#     version: '1.8.1',
#     score: 5,
#     title: 'Houseparty review',
#     text: 'I think houseparty is a really good app for phones that don’t have FaceTime or google duo. I just think there needs to be a few adjustments. Like I wish the connection for this was better. And most of the time it isn’t really working for me. The persons screen I am talking to doesn’t match up the words to there screen. Overall the app is a really good app and I do recommend it to other people like friends and family. I don’t like the fact that you can ghost people and they don’t even know it. I think you should get a little notification saying ( example of random people) Suzy ghosted you because she doesn’t want to talk to you right now. But, overall those are my only complaints. I really like this app. 😉😉😉',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2958011799',
#     userName: 'Sami_TT',
#     userUrl: 'https://itunes.apple.com/us/reviews/id442359074',
#     version: '1.13.5',
#     score: 5,
#     title: 'Bless houseparty',
#     text: 'When I use this app, I have a tendency to sit at the room next to our living room. Only with this app I do this. Today I was talking to my friends and was showing them the view and We witnessed a car accident. The car that got hit received a huge blow($2000 worth) It took me a minute to realize, that car that just got hit, was my dad’s. Thanks to this app I witnessed a car accident and was able to settle things with the person who caused the accident quickly as opposed to my dad seeing his car jacked up the next morning and going through the trouble of finding the person and calling the police and whatnot. And for this, I would like to thank the creators of houseparty for saving my dad hours from his life. Bless this app.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5732232189',
#     userName: 'House Party King',
#     userUrl: 'https://itunes.apple.com/us/reviews/id703315283',
#     version: '1.34.1',
#     score: 5,
#     title: 'Great way to quarantine and chill!',
#     text: 'I’ve never written an app review before, but after using this for the first time last night with friends in the midst of our covid-19 social distancing/quarantine, we all had such a great time with it that I decided to write a review to show full support. It’s a wonderful way to socialize and play games with people despite being far away from each other. We turned the games we played into drinking games, and it felt like we were all partying together, only it was all done virtually lol. The games do need a little update as far as more categories/cards/options, otherwise they can get repetitive, but I hope the developers are working on introducing that soon. Thank you for the amazing app!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4845911228',
#     userName: 'Ashley 🙃',
#     userUrl: 'https://itunes.apple.com/us/reviews/id1076679399',
#     version: '1.34.1',
#     score: 4,
#     title: 'Amazing 💖',
#     text: 'I love HouseParty it’s really easy for me to talk to my friends especially because I can know if there available or not just by seeing if there in the house. I love it, FaceTime has given me issues in the past year because of Group FaceTime. It wouldn’t let me and my friends be on it. But then we found HouseParty and we absolutely loved it. There is a little bug though. Every time we try to get in a call or something it kicks one of us out, and it stops HouseParty. But maybe that’s just us? Well other than that HouseParty is super amazing and if you fix the bug I’ll be happy from night and day. But anyways I’ve had HouseParty for over a a year and I definitely recommend this app because it’s definitely suitable for all ages who’s re aloud to talk to the friends on any electronic!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '4254227345',
#     userName: 'aun15drea_🤪',
#     userUrl: 'https://itunes.apple.com/us/reviews/id664058764',
#     version: '1.33.1',
#     score: 3,
#     title: 'It’s good but very glitchy',
#     text: 'I love houseparty and everything about it but I just had a severe glitch and tried everything to fix it. I was talking with my friend and all of a sudden it says we are not in the same room but we were. So we tried leaving and joining again. But then it said try joining again because there was a problem, this happened many times and got very annoying. I was so frustrated and so was my friend. I even tried turning off my phone and turning it back on and it still didn’t work. I tried getting off my WiFi and going on cellular data and it still didn’t work. So we just stoped trying and we are gonna try again later. My houseparty is fully up to date so that is not the problem. I don’t know what is. Please fix it because it makes me want to delete the app and just Group FaceTime.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5670872730',
#     userName: 'CLK😊',
#     userUrl: 'https://itunes.apple.com/us/reviews/id850100975',
#     version: '1.34.1',
#     score: 5,
#     title: 'Amazing app with one problem...',
#     text: 'I have had this app for quite a while and I find it very useful to me and my friends. I have lots of friends and things don’t work out if I can only call one of them at a time! Houseparty helps a ton for me! My friends have friends that they invite and it gets a little crowded. \n\n   The only things about this app is that there is a limit of 8 people. Sometimes it is a little frustrating when you can only have 8 people in the house. \n\nLastly, I would definitely recommend this app to anyone who is looking for an app to call all of their friends at once! Personally I would rate this a 4/5! But it still is a really amazing app even though it has a limit of people.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3955324274',
#     userName: 'pro review kid',
#     userUrl: 'https://itunes.apple.com/us/reviews/id966686076',
#     version: '1.29.0',
#     score: 1,
#     title: 'Not working 😡😡😡',
#     text: 'I downloaded this app to chat with all my other friends, but as soon as I downloaded it it started having problems. I was trying to make an account and every time I inputted something it said "error". I asked my friends if this happened to them and they said it had to do with the Wi-Fi, so I connected to Wi-Fi and it finally let me make an account. Now 30 minutes later I have an account. Then I texted all my friends to get on house party chat and when I try to friend them it gives me another error message. Now I\'m really frustrated with it but I decide to give the app another chance. So I connect to another Wi-Fi network and it still is giving me this error message! Honestly I don\'t know if it\'s my phone or the app but I am really upset with the service of this app. I hope I can get an explanation, this can be fixed, or both, but so far I had really high hopes for this app but it turned out horrible.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2291835010',
#     userName: 'Hddhjfhhzd',
#     userUrl: 'https://itunes.apple.com/us/reviews/id456510232',
#     version: '1.7.0',
#     score: 5,
#     title: 'Kicking annoying guests',
#     text: 'So I use house party a lot and people join and blast music so me and my friends can’t talk so could we get a kick eying to where someone nominates a kick and everyone in the call can vote on kicking that person and it could be anonymous but it tells the person that was kicked that they were too loud and they can still join back it would just be a warning system just so people can talk if they want and if they are kicked twice then they can wait or interact with other people in the meantime. I personally think it would be good just within how you guys would like to make it because people could spam kick but there could be a countdown timer and stuff like that.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5805498483',
#     userName: 'The opposite of relaxed',
#     userUrl: 'https://itunes.apple.com/us/reviews/id210970333',
#     version: '1.40.2',
#     score: 2,
#     title: 'Control Issues',
#     text: 'I should be able to open the app without my camera on. To get to controls even to learn I am immediately available and on screen. I should be able to enable my camera and be available after I open and choose right from the beginning.\n\nI see there is a sneak mode. I find that to be very dangerous. To allow someone to be a voyeur of others without the knowledge is both dangerous and sketchy.\n\nTo be able to learn anything about the app and its settings etc , I had to open it early in the morning to ensure no one would just in with me. Also the camera is on when I open. Its a horrible operating system.\n\nI have friends on this but find myself constantly avoiding opening because almost every time I have been caught off guard.\n\nIt would be great if the app opened without the camera, allowed you to enable it and choose to let people know you are on. When you join, it should walk you through how it works and the available settings (including the camera/available option), so that a new user understands how to set privacy and can do so without being bombarded by people unexpectedly.\n\nThis app is a great idea especially in these times, but it really needs some changes to ensure privacy and accessibility of features.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '2639386822',
#     userName: 'Abdulla Taymour',
#     userUrl: 'https://itunes.apple.com/us/reviews/id818920644',
#     version: '1.11.2',
#     score: 5,
#     title: 'Life saving app',
#     text: 'I would like to thank the app’s team and developers. This app is a life saver. I am currently studying in the US as an international student for almost a year now, and I have not returned home in 6 months. I have only felt homesick a couple of time in these 6 months because of this app. I talk with my family and friends almost daily. The quality of the video is just amazing. It surpasses many video call services. Without this app I would have felt sad and almost depressed. Keep up the amazing work. \n\nPS: your device will become a little hot when you use this app for a long period of time. I think this is because the app is compressing and decompressing the videos to give good quality.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3003658944',
#     userName: 'kejulius22',
#     userUrl: 'https://itunes.apple.com/us/reviews/id580555691',
#     version: '1.14.0',
#     score: 5,
#     title: 'Great app',
#     text: 'All of my friends have it so it’s great for making plans quickly. Texting is so hard because some people don’t look at their phones a lot so when you ring them they get a call so that’s better. And texting isn’t as clear as Housepartying because things get whacked up when you text. Also great for group projects for school because sometimes the teachers are mean and give us like a week to do a project and no one can get together so we can talk on the phone with EVERYBODY instead of face time wick is only two people and you can’t FaceTime someone who doesn’t have a iPhone so Houseparty is great. It’s an all in one app that’s really fun and it’s wayyyy better then Skype.😋',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5798873218',
#     userName: 'kshusker88',
#     userUrl: 'https://itunes.apple.com/us/reviews/id643062173',
#     version: '1.40.2',
#     score: 3,
#     title: 'Great way to keep in touch and have fun',
#     text: 'This is a great app to keep in touch with friends and see each other and play games especially now with social distancing. But there just isn’t a lot of variety of games to play on here and the trivia game doesn’t give you enough time to read before you answer. When you are having fun, laughing and talking trying to read too takes time, before you know it time is up. Wish there was a way to add an adult version of chips and quac like cards against humanity. Other than that this is a great way to keep in touch with everyone. But if your playing in the same house make sure you sit away from the other person or they mute and turn down their volume or you’ll get a horrible hamster wheel sound going on the whole time.',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5792332008',
#     userName: 'lydia900',
#     userUrl: 'https://itunes.apple.com/us/reviews/id395727796',
#     version: '1.40.2',
#     score: 4,
#     title: 'More Games!',
#     text: 'Because of the pandemic, I haven’t been able to see my family or have family game nights like we used to. We played for over four hours on this app and it was hilarious and just so much fun. \nI just wish that there were more games to play or more variety to the games. If you need some help, I now have plenty of time to help with this stay at home order. More trivia, more chips and guac cards, more headbandz, more draw this! \nOverall this is a wonderful app to have during this pandemic and I wouldn’t be able to have my regular family game nights without it. Thank you so much for making this app, and I would really like to help expand it in any way I can to keep people entertained during the COVID-19 panic!!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5717993314',
#     userName: 'memaaljaiban',
#     userUrl: 'https://itunes.apple.com/us/reviews/id462092542',
#     version: '1.34.1',
#     score: 5,
#     title: 'M.L',
#     text: 'Why I think house party needs more updates or changes \n\nSo houseparty is a fund and cool app you may contact family and friends but the only thing that disturbers me is that you cannot send pictures or videos facemails could come in handy but I would like to say house party is the best free app as I said u\nYou may contact friends and family for example if you are a child have no phone but iPad you may contact you mom or dad by saying in the type in chat or type in private chat you may have more then 1 account logged in witch is cool!!\n\nHouseparty is also a cool app because you can play games with friends and family you can call even though the person is on the other side of the world you may communicate with family as I said before but houseparty has a lot of lag outs so the person suddenly leaves the call and they say they didn’t and neither did you so that me the cal lagged out and it makes it hard to play with friends if they keep on leaving and I hope one day they fix it up.\n\nHouse party is amazing but now it has a lot of lag outs it’s annoying',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5091976241',
#     userName: 'Vanessa Counser',
#     userUrl: 'https://itunes.apple.com/us/reviews/id849854791',
#     version: '1.34.1',
#     score: 5,
#     title: 'Awesome!!! ;ᴘ',
#     text: 'This app is great.🙌🏼 🙌🏼There are so many good things i could say about this app but i will only talk about the main things for now. ☝🏼First of all i love how you can talk to more than one person at once.💟 Once i have talked to like 7/8 people at once.😺I love how when you are not talking to anyone there are just random useless but interesting facts on the screen that keep me up until 2am.🤣 This app is great quality and is probably one of the best FaceTime/video call apps.👍🏼i also like that it tells you if someone you haven’t friended joins the call. 🙏🏼This app has great privacy.🙏🏼 I definitely recommend this app. It is amazing!!!❤️💛💚💙💗👍🏼👍🏼👍🏼👏🏼i👏🏼dare👏🏼you👏🏼to👏🏼get👏🏼this👏🏼app👏🏼😹',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3721694820',
#     userName: 'Lollooppopsicle',
#     userUrl: 'https://itunes.apple.com/us/reviews/id26275179',
#     version: '1.25.2',
#     score: 5,
#     title: 'Awesome app!',
#     text: 'This is an amazing app for keeping in touch with friends! In this day and age, if you want to talk with a group of friends, you most likely just text them! We need more face to face communication! But that is not possible with groups of 3 or more people! Let’s face it! An app like this should have been invented a long time ago! Houseparty is an amazing app to help you chat it up (and even play a few games of Heads up) with friends! It also isn’t focused around who gets the most likes or who has the most friends like a lot of social media apps. Get out of your comfort zone and invite a casual friend into your room and introduce them to your other friends! Time to have some fun :)',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '3083576986',
#     userName: 'Denim Glover',
#     userUrl: 'https://itunes.apple.com/us/reviews/id889151908',
#     version: '1.15.0',
#     score: 5,
#     title: 'Houseparty',
#     text: 'Houseparty is an amazing app to talk to your friends it’s so fun you have the option to get an notifications and you have the option to change that decision at any time if you don’t want to change your decision but just want an hour of silence you can scroll down on the notifications and you have the option to sneak in the house mean your friends don’t get an notifications or silent for an hour or sometimes send a note you press silence for an hour and you don’t get an notifications for an whole hour it’s an amazing app to talk to 8 of your friends and under just the best way to here there voices and more you should download Houseparty it’s an amazing app',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' },
#   { id: '5688788163',
#     userName: 'AestheticallyLeona',
#     userUrl: 'https://itunes.apple.com/us/reviews/id998052839',
#     version: '1.34.1',
#     score: 5,
#     title: 'I love this app!',
#     text: 'Dear Houseparty,\n\nThank you for making video calls/texting epic. You truly connect people. I have some new suggestions/statements. Yes, I have edited this review many times but I just love Houseparty!\n\n1. Make the “facemail” camera better. It’s only on HP that my camera is bad. \n2. Make a dark mode\n3. Make it where you can send pictures when texting other people.\n4. Stay awesome.\n5. Thank you for making trivia free!!! It is so so awesome to not have to pay for it!\n6. Please add more games. While your games are fun, it would be EPIC to have some more games to play.\n7. Make it were best friends last forever. Once a best friend always a best friend. Make a recommended section where it’s easier to call those best friends.\n8. Thank you for connecting everyone and strengthening friendships!!\n\nI literally use this app every single day whether that means calling my best friends during the season of COVID-19 or playing trivia by myself because I am bored (😂). Thank you for listening to your users! Peace out, HP! Hopefully this review was helpful!\n\nYours Truly,\nAnother Anonymous and HP lovin’ user!',
#     url: 'https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software' } ]

# %%
json_list = []
    
with open('./data/sample.json',encoding='utf-8', errors='ignore') as json_file:
    x = eval(json_file.read()) 
    print(x[0])
    #data = json.loads(json_file.read())


for i in x:
    json_list.append(json.loads(i))
# Out:
# {"id":"5675067217","userName":"bling.blazer","userUrl":"https://itunes.apple.com/us/reviews/id948229368","version":"1.34.1","score":4,"title":"Unique and helpful😀","text":"I downloaded houseparty maybe two years ago and one of the great things about it is you get the chance to talk to people you wouldn’t usually talk to or call on purpose and you make a lot of new friends this way. One of my best friends to this day I would’ve never thought of talking to if it hadn’t been for houseparty. It’s a great app overall the only reason it lost that star was because of what it did with streaks. It started off cool like you and your friends would try to rack up minutes and because it was every five days in circumstances where they couldn’t be on house party I felt it was a good amount of time to give. But then they began decreasing it to three and then two days which means you basically have to be on the app everyday in order to keep your minutes or streak or whatever. It’s not really the fact that minutes and aesthetic were lost but more of the passive aggressive way to keep people on the app. Minutes were one out of many of my motivations to go back to the app knowing i had a good amount of time, but now there’s no motivation if you’re just going to lose them every two days. But overall it is still a very good app and helpful in making new friends","url":"https://itunes.apple.com/us/review?id=1065781769&type=Purple%20Software"}

# %%
json_list = []
with open('./data/ios_data.json',encoding='utf-8', errors='ignore') as json_file:
    string_json =  '[' + json_file.read() + ']'
    #print(string_json)
    x = eval(string_json.replace(']', '],')) 
    #print(json_file.read().replace(']', '],'))

for i in x[0]:
    for j in i:
        review_entry = json.loads(j)
        p = re.compile("\?id=([a-z0-9\-]+)\&?")
        result = p.search(sample_entry['url'])
        appid = result.group(1)
        review_entry['appid'] = appid
        json_list.append(review_entry)

print(json_list[0]['appid'])
# Out:
# 454638411

# %%
test = json.loads(x[0][0][0])
print(type(test))
# Out:
# <class 'dict'>

# %%
json_list[0]
# Out:
# {'id': '5894396330',
#  'userName': 'natalijapav',
#  'userUrl': 'https://itunes.apple.com/us/reviews/id930309969',
#  'version': '262.1',
#  'score': 1,
#  'title': 'Absolutely terrible',
#  'text': "I am literally writing this after this app crashed while I was using it. I don't even know where I should start. After the update with the new look of the app everything just went terribly wrong. First off, the bugs. I keep restarting this app dozens of times a day in order for it to work properly. Messages won't load, there are bugs with the media overall, especially videos that don't play properly most of the time and how low quality they are. I am pretty sure that there's no problem with my phone nor with my internet connection, because everything else on my phone works perfectly fine. Let's not mention how late my messages are. This happens every day: I send a dozen messages and neither of those are appearing on my screen and I have to wait up a bit until they're sent. And the pen - it's just horrible. I saw that now I can change the thickness of it, but it is terrible anyway - the previous version of it was undoubtely better. I saw people talking about how new updates removed everything that made Messenger unique and the reasons why people still used it even though apps such as WhatsApp and Viber are more popular nowadays. I remember when Messenger used to be my favorite app for chatting. I've been using it for past 5 years on a daily basis. It is hard to find another platform where I can text with my friends because we got so used to this app. PLEASE FIX THE BUGS if not anything else.",
#  'url': 'https://itunes.apple.com/us/review?id=454638411&type=Purple%20Software',
#  'appid': '454638411'}

# %%
df = pd.DataFrame(json_list)
df.to_csv('./data/ios.csv', index = False)

# %%
#add categories data to csv
social = ["1065781769","1096918571","454638411","284882215","985746746","985746746","1462082664","643496868","304878510","686449807"]
games = ["1344700142","1490384223","1094591345","1499812410","664575829","1498817833","1494449873","623592465","1500564080","406889139"]
health_and_fitness = ["571800810","301521403","387771637","1099771240","634598719","1168348542","462638897","1241229134","300235330","487847188", "1361619409"]
travel = ["293622097","368677368","529379082","401626263","1245772818","904418768","989307692","288113403","336381998","1438670520","474259675","533365777"]
utility = ["868077558","1178765645","416023011","309172177","491126018","926252661","942608209","621574163","1200318119","561625752","917932200"]
education = ["924620788","570060128","756972930","919087726","522826277","552602056","467329677","469863705","875063456","453142230","950424861","546473125","977976646"]
lifestyle = ["429047995","1490078757","680819774","944011620","930441707","1161035371","1222822904","463630399","1462195529","464988855","1288415553","1459289784"]



master_list = [social, games, health_and_fitness, travel, utility, education, lifestyle]
category_dict = {0: "social", 1: "games", 2:"health_and_fitness", 3:"travel", 4:"utility", 5:"education", 6:"lifestyle"}
master_dict = {}
for index, i in enumerate(master_list):
    for j in i:
        master_dict[j] = category_dict[index]

master_dict
# Out:
# {'1065781769': 'social',
#  '1096918571': 'social',
#  '454638411': 'social',
#  '284882215': 'social',
#  '985746746': 'social',
#  '1462082664': 'social',
#  '643496868': 'social',
#  '304878510': 'social',
#  '686449807': 'social',
#  '1344700142': 'games',
#  '1490384223': 'games',
#  '1094591345': 'games',
#  '1499812410': 'games',
#  '664575829': 'games',
#  '1498817833': 'games',
#  '1494449873': 'games',
#  '623592465': 'games',
#  '1500564080': 'games',
#  '406889139': 'games',
#  '571800810': 'health_and_fitness',
#  '301521403': 'health_and_fitness',
#  '387771637': 'health_and_fitness',
#  '1099771240': 'health_and_fitness',
#  '634598719': 'health_and_fitness',
#  '1168348542': 'health_and_fitness',
#  '462638897': 'health_and_fitness',
#  '1241229134': 'health_and_fitness',
#  '300235330': 'health_and_fitness',
#  '487847188': 'health_and_fitness',
#  '1361619409': 'health_and_fitness',
#  '293622097': 'travel',
#  '368677368': 'travel',
#  '529379082': 'travel',
#  '401626263': 'travel',
#  '1245772818': 'travel',
#  '904418768': 'travel',
#  '989307692': 'travel',
#  '288113403': 'travel',
#  '336381998': 'travel',
#  '1438670520': 'travel',
#  '474259675': 'travel',
#  '533365777': 'travel',
#  '868077558': 'utility',
#  '1178765645': 'utility',
#  '416023011': 'utility',
#  '309172177': 'utility',
#  '491126018': 'utility',
#  '926252661': 'utility',
#  '942608209': 'utility',
#  '621574163': 'utility',
#  '1200318119': 'utility',
#  '561625752': 'utility',
#  '917932200': 'utility',
#  '924620788': 'education',
#  '570060128': 'education',
#  '756972930': 'education',
#  '919087726': 'education',
#  '522826277': 'education',
#  '552602056': 'education',
#  '467329677': 'education',
#  '469863705': 'education',
#  '875063456': 'education',
#  '453142230': 'education',
#  '950424861': 'education',
#  '546473125': 'education',
#  '977976646': 'education',
#  '429047995': 'lifestyle',
#  '1490078757': 'lifestyle',
#  '680819774': 'lifestyle',
#  '944011620': 'lifestyle',
#  '930441707': 'lifestyle',
#  '1161035371': 'lifestyle',
#  '1222822904': 'lifestyle',
#  '463630399': 'lifestyle',
#  '1462195529': 'lifestyle',
#  '464988855': 'lifestyle',
#  '1288415553': 'lifestyle',
#  '1459289784': 'lifestyle'}

# %%
import pandas as pd
ios_df = pd.read_csv('./data/ios.csv')

ios_df
# Out:
#           appid          id  score  \
# 0     454638411  5894396330      1
# 1     454638411  5849275727      2
# 2     454638411  5783600952      1
# 3     454638411  5761166297      1
# 4     454638411  5699902519      3
# 5     454638411  5290519753      3
# 6     454638411  5628934498      1
# 7     454638411  5572276909      1
# 8     454638411  5599301863      1
# 9     454638411  5788124258      3
# 10    454638411  5783743531      1
# 11    454638411  5609522979      5
# 12    454638411  5595038671      1
# 13    454638411  5653401292      1
# 14    454638411  5732657443      1
# 15    454638411  5643107719      1
# 16    454638411  5662390474      1
# 17    454638411  3712049643      1
# 18    454638411  5436302326      2
# 19    454638411  2093530036      2
# 20    454638411  3761925446      3
# 21    454638411  5259874100      3
# 22    454638411  2003091192      3
# 23    454638411  3435907881      2
# 24    454638411  2697160709      1
# 25    454638411  1893436053      3
# 26    454638411  5878247603      1
# 27    454638411  5725207069      4
# 28    454638411  5620395278      1
# 29    454638411  5611717014      3
# ...         ...         ...    ...
# 3871  463630399  5456886173      3
# 3872  463630399  4467803351      2
# 3873  463630399  2346831834      4
# 3874  463630399  2698187285      4
# 3875  463630399  3482352667      3
# 3876  463630399  1977469218      1
# 3877  463630399  2642361329      2
# 3878  463630399  3756790080      5
# 3879  463630399  2893646545      2
# 3880  463630399  2865219885      5
# 3881  463630399  1827337717      5
# 3882  463630399  2822236832      5
# 3883  463630399  2663521795      5
# 3884  463630399  5113329782      5
# 3885  463630399  4910189779      1
# 3886  463630399  4787802698      2
# 3887  463630399  2493269296      1
# 3888  463630399  3210733563      5
# 3889  463630399  3006876276      3
# 3890  463630399  1914077651      5
# 3891  463630399  3994925843      2
# 3892  463630399  3444120020      4
# 3893  463630399  2894099922      3
# 3894  463630399  1862704283      4
# 3895  463630399  5276394433      5
# 3896  463630399  2577958286      5
# 3897  463630399  1928106433      3
# 3898  463630399  2038622069      3
# 3899  463630399  5808712464      3
# 3900  463630399  2242628543      2
#
#                                                    text  \
# 0     I am literally writing this after this app cra...
# 1     Soooo, no matter what, this app can’t be bypas...
# 2     Well did an update on Tuesday, & it hasn’t wor...
# 3     The new update is absolutely disgusting. It ma...
# 4     I don’t do reviews at all but messenger for th...
# 5     There needs to be a better notification when s...
# 6     Facebook and messenger are always changing. Th...
# 7     The title seems harsh, but you need to know ho...
# 8     Cmon people. Seriously stop with the completel...
# 9     I feel as if that app deserved 3 stars from us...
# 10    Honestly a lot of the features being removed I...
# 11    I can’t believe you finally removed all the tr...
# 12    They have changed a few things on this latest ...
# 13    The new update has my app logging my account o...
# 14    For the past month, I haven’t been able to log...
# 15    😡😤 I absolutely hate this new version of messe...
# 16    What a dumpster fire of an app. I’ve always ha...
# 17    Most of the people I’ve seen have just been co...
# 18    Hello how is everyone doing?  I’m wondering wh...
# 19    Facebooks messenger app is a pointless applica...
# 20    Although I have connected with some amazing pe...
# 21    I don't normally leave reviews, but i feel tha...
# 22    Compared to previous versions of the app this ...
# 23    I recently updated my messenger and it’s weird...
# 24    I’ve just updated the apps in few minutes ago ...
# 25    Always been a big loyal fan of Facebook’s Mess...
# 26    I no longer receive Messenger alerts or messag...
# 27    I’m not trying to write a bad review or anythi...
# 28    Useful and fun features were unnecessarily rem...
# 29    I’m not sure if these are happening while Mess...
# ...                                                 ...
# 3871  I seriously love Pink leggings!! The love the ...
# 3872  I do not understand how this app is a 4.8 with...
# 3873  I love PINK VS, and now I have an app to shop ...
# 3874  I love it! Very useful to view the new clothes...
# 3875  I LOVE this app and I love seeing what’s new! ...
# 3876  I installed apps for Black Friday sales which ...
# 3877  I tried to take off items from my shopping car...
# 3878  There’s something about putting on Victoria’s ...
# 3879  I don’t like the app’s set up. The way that yo...
# 3880  Oh my gosh, this app is SO cool and I love bei...
# 3881  I love PINK! This helps me look and shop for m...
# 3882  Every girl loves PINK—their clothing and under...
# 3883  I love Pink and using apps compared to the act...
# 3884  Two weeks ago I purchased lots of stuff exchan...
# 3885  Make an actual app. This web based bs is trash...
# 3886  This app would be a 4 star if it wasn’t for th...
# 3887  I log in and all my info is entered and saved ...
# 3888  The app isn’t user friendly most of the time i...
# 3889  Honestly, this app has its few up and downs. A...
# 3890  Hi. My names Hailey. I just got interested in ...
# 3891  If you're a type of person who chose comfort o...
# 3892  The app is amazing overall but for some reason...
# 3893  I’ve had this app for years now. Lately it has...
# 3894  I love the app and getting notifications on th...
# 3895  The other day Black Friday eve I had the worst...
# 3896  While I love the app I do not enjoy using it f...
# 3897  I’ve found the app to work when it wants to, v...
# 3898  I shop in PINK 24/7, but everytime I attempt t...
# 3899  I am very confused on why it does not have a w...
# 3900  it’s a great app for window shopping online bu...
#
#                                                   title  \
# 0                                   Absolutely terrible
# 1                        Give the people what they want
# 2                                         Please fix...
# 3                    New Update is Trash, Useless (iOS)
# 4                          Messenger may have a problem
# 5                      A couple things need to be fixed
# 6                                New update is horrible
# 7                     New Update is Absolutely Horrible
# 8                       Stop making unnecessary changes
# 9                                          Fair review.
# 10        Staple features removed and NOW breaking bugs
# 3895  https://itunes.apple.com/us/reviews/id1080052391   7.5.1
# 3896   https://itunes.apple.com/us/reviews/id324094903    4.21
# 3897    https://itunes.apple.com/us/reviews/id43440299    4.18
# 3898   https://itunes.apple.com/us/reviews/id337763882    4.19
# 3899   https://itunes.apple.com/us/reviews/id558421549   8.0.0
# 3900   https://itunes.apple.com/us/reviews/id286883531    4.20
#
# [3901 rows x 9 columns]

# %%
def apply_category(row):
    return master_dict[str(row['appid'])]
ios_df['category'] = ios_df.apply (lambda row: apply_category(row), axis=1)

# %%
ios_df
# Out:
#           appid          id  score  \
# 0     454638411  5894396330      1
# 1     454638411  5849275727      2
# 2     454638411  5783600952      1
# 3     454638411  5761166297      1
# 4     454638411  5699902519      3
# 5     454638411  5290519753      3
# 6     454638411  5628934498      1
# 7     454638411  5572276909      1
# 8     454638411  5599301863      1
# 9     454638411  5788124258      3
# 10    454638411  5783743531      1
# 11    454638411  5609522979      5
# 12    454638411  5595038671      1
# 13    454638411  5653401292      1
# 14    454638411  5732657443      1
# 15    454638411  5643107719      1
# 16    454638411  5662390474      1
# 17    454638411  3712049643      1
# 18    454638411  5436302326      2
# 19    454638411  2093530036      2
# 20    454638411  3761925446      3
# 21    454638411  5259874100      3
# 22    454638411  2003091192      3
# 23    454638411  3435907881      2
# 24    454638411  2697160709      1
# 25    454638411  1893436053      3
# 26    454638411  5878247603      1
# 27    454638411  5725207069      4
# 28    454638411  5620395278      1
# 29    454638411  5611717014      3
# ...         ...         ...    ...
# 3871  463630399  5456886173      3
# 3872  463630399  4467803351      2
# 3873  463630399  2346831834      4
# 3874  463630399  2698187285      4
# 3875  463630399  3482352667      3
# 3876  463630399  1977469218      1
# 3877  463630399  2642361329      2
# 3878  463630399  3756790080      5
# 3879  463630399  2893646545      2
# 3880  463630399  2865219885      5
# 3881  463630399  1827337717      5
# 3882  463630399  2822236832      5
# 3883  463630399  2663521795      5
# 3884  463630399  5113329782      5
# 3885  463630399  4910189779      1
# 3886  463630399  4787802698      2
# 3887  463630399  2493269296      1
# 3888  463630399  3210733563      5
# 3889  463630399  3006876276      3
# 3890  463630399  1914077651      5
# 3891  463630399  3994925843      2
# 3892  463630399  3444120020      4
# 3893  463630399  2894099922      3
# 3894  463630399  1862704283      4
# 3895  463630399  5276394433      5
# 3896  463630399  2577958286      5
# 3897  463630399  1928106433      3
# 3898  463630399  2038622069      3
# 3899  463630399  5808712464      3
# 3900  463630399  2242628543      2
#
#                                                    text  \
# 0     I am literally writing this after this app cra...
# 1     Soooo, no matter what, this app can’t be bypas...
# 2     Well did an update on Tuesday, & it hasn’t wor...
# 3     The new update is absolutely disgusting. It ma...
# 4     I don’t do reviews at all but messenger for th...
# 5     There needs to be a better notification when s...
# 6     Facebook and messenger are always changing. Th...
# 7     The title seems harsh, but you need to know ho...
# 8     Cmon people. Seriously stop with the completel...
# 9     I feel as if that app deserved 3 stars from us...
# 10    Honestly a lot of the features being removed I...
# 11    I can’t believe you finally removed all the tr...
# 12    They have changed a few things on this latest ...
# 13    The new update has my app logging my account o...
# 14    For the past month, I haven’t been able to log...
# 15    😡😤 I absolutely hate this new version of messe...
# 16    What a dumpster fire of an app. I’ve always ha...
# 17    Most of the people I’ve seen have just been co...
# 18    Hello how is everyone doing?  I’m wondering wh...
# 19    Facebooks messenger app is a pointless applica...
# 20    Although I have connected with some amazing pe...
# 21    I don't normally leave reviews, but i feel tha...
# 22    Compared to previous versions of the app this ...
# 23    I recently updated my messenger and it’s weird...
# 24    I’ve just updated the apps in few minutes ago ...
# 25    Always been a big loyal fan of Facebook’s Mess...
# 26    I no longer receive Messenger alerts or messag...
# 27    I’m not trying to write a bad review or anythi...
# 28    Useful and fun features were unnecessarily rem...
# 29    I’m not sure if these are happening while Mess...
# ...                                                 ...
# 3871  I seriously love Pink leggings!! The love the ...
# 3872  I do not understand how this app is a 4.8 with...
# 3873  I love PINK VS, and now I have an app to shop ...
# 3874  I love it! Very useful to view the new clothes...
# 3875  I LOVE this app and I love seeing what’s new! ...
# 3876  I installed apps for Black Friday sales which ...
# 3877  I tried to take off items from my shopping car...
# 3878  There’s something about putting on Victoria’s ...
# 3879  I don’t like the app’s set up. The way that yo...
# 3880  Oh my gosh, this app is SO cool and I love bei...
# 3881  I love PINK! This helps me look and shop for m...
# 3882  Every girl loves PINK—their clothing and under...
# 3883  I love Pink and using apps compared to the act...
# 3884  Two weeks ago I purchased lots of stuff exchan...
# 3885  Make an actual app. This web based bs is trash...
# 3886  This app would be a 4 star if it wasn’t for th...
# 3887  I log in and all my info is entered and saved ...
# 3888  The app isn’t user friendly most of the time i...
# 3889  Honestly, this app has its few up and downs. A...
# 3890  Hi. My names Hailey. I just got interested in ...
# 3891  If you're a type of person who chose comfort o...
# 3892  The app is amazing overall but for some reason...
# 3893  I’ve had this app for years now. Lately it has...
# 3894  I love the app and getting notifications on th...
# 3895  The other day Black Friday eve I had the worst...
# 3896  While I love the app I do not enjoy using it f...
# 3897  I’ve found the app to work when it wants to, v...
# 3898  I shop in PINK 24/7, but everytime I attempt t...
# 3899  I am very confused on why it does not have a w...
# 3900  it’s a great app for window shopping online bu...
#
#                                                   title  \
# 0                                   Absolutely terrible
# 1                        Give the people what they want
# 2                                         Please fix...
# 3                    New Update is Trash, Useless (iOS)
# 4                          Messenger may have a problem
# 5                      A couple things need to be fixed
# 6                                New update is horrible
# 7                     New Update is Absolutely Horrible
# 8                       Stop making unnecessary changes
# 9                                          Fair review.
# 10        Staple features removed and NOW breaking bugs
# 11            Nice update the app is cleaner and faster
# 12                          New update is total garbage
# 13    App is glitching and removed a whole bunch of ...
# 14                                          Can’t Login
# 15                                               Active
# 16                         This app is an absolute joke
# 17                          New update looks really bad
# 18              Why not Apple CarPlay like messages has
# 19                                            Pointless
# 20                          Not Horrible but Has Issues
# 21                                Somewhat an annoyance
# 22                Great but definitely could be better!
# 23                                        Newest Update
# 24                                Latest update problem
# 25                               Post iOS 11.0.3 issues
# 26                                       What happened?
# 27                                 Please Do This !!!!!
showAllReviews=true","https://play.google.com/store/apps/details?id=com.google.android.apps.classroom&showAllReviews=true","https://play.google.com/store/apps/details?id=com.duolingo&showAllReviews=true","https://play.google.com/store/apps/details?id=com.vidku.app.flipgrid&showAllReviews=true","https://play.google.com/store/apps/details?id=com.microblink.photomath&showAllReviews=true","https://play.google.com/store/apps/details?id=com.remind101&showAllReviews=true","https://play.google.com/store/apps/details?id=com.classdojo.android&showAllReviews=true","https://play.google.com/store/apps/details?id=com.bagatrix.mathway.android&showAllReviews=true","https://play.google.com/store/apps/details?id=org.khanacademy.android&showAllReviews=true","https://play.google.com/store/apps/details?id=com.wonder&showAllReviews=true","https://play.google.com/store/apps/details?id=com.piazza.android&showAllReviews=true","https://play.google.com/store/apps/details?id=com.blackboard.android.bbstudent&showAllReviews=true","https://play.google.com/store/apps/details?id=com.quizlet.quizletandroid&showAllReviews=true","https://play.google.com/store/apps/details?id=co.brainly&showAllReviews=true","https://play.google.com/store/apps/details?id=com.pinterest&showAllReviews=true","https://play.google.com/store/apps/details?id=com.c2m.frankly&showAllReviews=true","https://play.google.com/store/apps/details?id=com.google.android.apps.chromecast.app&showAllReviews=true","https://play.google.com/store/apps/details?id=com.amazon.dee.app&showAllReviews=true","https://play.google.com/store/apps/details?id=com.bumble.app&showAllReviews=true","https://play.google.com/store/apps/details?id=com.prayapp.client&showAllReviews=true","https://play.google.com/store/apps/details?id=com.samsung.android.oneconnect&showAllReviews=true","https://play.google.com/store/apps/details?id=com.victoriassecret.pinknation&showAllReviews=true","https://play.google.com/store/apps/details?id=com.survjun&showAllReviews=true","https://play.google.com/store/apps/details?id=com.nest.android&showAllReviews=true","https://play.google.com/store/apps/details?id=com.hualai&showAllReviews=true","https://play.google.com/store/apps/details?id=com.arlo.app&showAllReviews=true"]
android_master_dict = {}

counter = 0
social_a = android_url_list[counter:counter + len(social)]
counter = counter + len(social)
games_a = android_url_list[counter:counter + len(games)]
counter = counter + len(games)
hf_a = android_url_list[counter: counter + len(health_and_fitness)]
counter = counter + len(health_and_fitness)
travel_a = android_url_list[counter:counter + len(travel)]
counter = counter + len(travel)
utility_a = android_url_list[counter: counter + len(utility)]
counter = counter + len(utility)
education_a = android_url_list[counter: counter + len(education)]
counter = counter + len(education)
lifestyle_a = android_url_list[counter: counter + len(lifestyle)]
counter = counter + len(lifestyle)

master_android_list = [social_a, games_a, hf_a, travel_a, utility_a, education_a, lifestyle_a]

import re
def get_android_id(url_string):
    p = re.compile(".+\\bdetails\\?id=([^&]+)")
    result = p.search(url_string)
    appid = result.group(1)
    return appid

for index, i in enumerate(master_android_list):
    for j in i:
        android_master_dict[get_android_id(j)] = category_dict[index]
# Out:
# {'com.herzick.houseparty': 'social',
#  'com.google.android.apps.tachyon': 'social',
#  'com.facebook.orca': 'social',
#  'com.facebook.katana': 'social',
#  'com.discord': 'social',
#  'com.whatsapp': 'social',
#  'com.popshow.yolo': 'social',
#  'com.google.android.talk': 'social',
#  'com.skype.raider': 'social',
#  'org.telegram.messenger': 'social',
#  'com.matteljv.uno': 'games',
#  'com.xmgame.savethegirl': 'games',
#  'com.nianticlabs.pokemongo': 'games',
#  'com.freeplay.runandfight': 'games',
#  'com.playrix.fishdomdd.gplay': 'games',
#  'com.fivebits.borderpatrol': 'games',
#  'com.playgendary.creamaster': 'games',
#  'com.wb.headsup': 'games',
#  'com.panteon.homesweethome': 'games',
#  'com.moonactive.coinmaster': 'games',
#  'com.calm.android': 'health_and_fitness',
#  'com.nike.ntc': 'health_and_fitness',
#  'com.nike.plusgps': 'health_and_fitness',
#  'com.bendingspoons.thirtydayfitness': 'health_and_fitness',
#  'com.wsl.noom': 'health_and_fitness',
#  'com.zerofasting.zero': 'health_and_fitness',
#  'com.fitbit.FitbitMobile': 'health_and_fitness',
#  'com.reflectlyApp': 'health_and_fitness',
#  'com.fitnesskeeper.runkeeper.pro': 'health_and_fitness',
#  'gov.cdc.general': 'health_and_fitness',
#  'net.beginners.weight.loss.workout.women.yoga.go': 'health_and_fitness',
#  'com.google.earth': 'travel',
#  'com.ubercab': 'travel',
#  'me.lyft.android': 'travel',
#  'com.airbnb.android': 'travel',
#  'com.vrbo.android': 'travel',
#  'com.google.android.street': 'travel',
#  'com.uhaul.android.myuhaul': 'travel',
#  'at.nk.tools.iTranslate': 'travel',
#  'com.priceline.android.negotiator': 'travel',
#  'com.spirit.customerapp': 'travel',
#  'com.pilottravelcenters.mypilot': 'travel',
#  'com.flistholding.flightplus': 'travel',
#  'com.bitstrips.imoji': 'utility',
#  'com.xfinity.digitalhome': 'utility',
#  'com.vzw.hss.myverizon': 'utility',
#  'com.att.myWireless': 'utility',
#  'com.sprint.care': 'utility',
#  'com.ringapp': 'utility',
#  'com.brighthouse.mybhn': 'utility',
#  'com.amazon.clouddrive.photos': 'utility',
#  'com.apple.qrcode.reader': 'utility',
#  'com.tmobile.pr.mytmobile': 'utility',
#  'com.riffsy.FBMGIFApp': 'utility',
#  'com.google.android.apps.classroom': 'education',
#  'com.duolingo': 'education',
#  'com.vidku.app.flipgrid': 'education',
#  'com.microblink.photomath': 'education',
#  'com.remind101': 'education',
#  'com.classdojo.android': 'education',
#  'com.bagatrix.mathway.android': 'education',
#  'org.khanacademy.android': 'education',
#  'com.wonder': 'education',
#  'com.piazza.android': 'education',
#  'com.blackboard.android.bbstudent': 'education',
#  'com.quizlet.quizletandroid': 'education',
#  'co.brainly': 'education',
#  'com.pinterest': 'lifestyle',
#  'com.c2m.frankly': 'lifestyle',
#  'com.google.android.apps.chromecast.app': 'lifestyle',
#  'com.amazon.dee.app': 'lifestyle',
#  'com.bumble.app': 'lifestyle',
#  'com.prayapp.client': 'lifestyle',
#  'com.samsung.android.oneconnect': 'lifestyle',
#  'com.victoriassecret.pinknation': 'lifestyle',
#  'com.survjun': 'lifestyle',
#  'com.nest.android': 'lifestyle',
#  'com.hualai': 'lifestyle',
#  'com.arlo.app': 'lifestyle'}

# %%
android_data = pd.read_csv('./data/android_data.csv')


def apply_android_category(row):
    return android_master_dict[row['appId']]
android_data['category'] = android_data.apply (lambda row: apply_android_category(row), axis=1)

# %%
android_data
# Out:
#                        appId  \
# 0     com.herzick.houseparty
# 1     com.herzick.houseparty
# 2     com.herzick.houseparty
# 3     com.herzick.houseparty
# 4     com.herzick.houseparty
# 5     com.herzick.houseparty
# 6     com.herzick.houseparty
# 7     com.herzick.houseparty
# 8     com.herzick.houseparty
# 9     com.herzick.houseparty
# 10    com.herzick.houseparty
# 11    com.herzick.houseparty
# 12    com.herzick.houseparty
# 13    com.herzick.houseparty
# 14    com.herzick.houseparty
# 15    com.herzick.houseparty
# 16    com.herzick.houseparty
# 17    com.herzick.houseparty
# 18    com.herzick.houseparty
# 19    com.herzick.houseparty
# 20    com.herzick.houseparty
# 21    com.herzick.houseparty
# 22    com.herzick.houseparty
# 23    com.herzick.houseparty
# 24    com.herzick.houseparty
# 25    com.herzick.houseparty
# 26    com.herzick.houseparty
# 27    com.herzick.houseparty
# 28    com.herzick.houseparty
# 29    com.herzick.houseparty
# ...                      ...
# 7842            com.arlo.app
# 7843            com.arlo.app
# 7844            com.arlo.app
# 7845            com.arlo.app
# 7846            com.arlo.app
# 7847            com.arlo.app
# 7848            com.arlo.app
# 7849            com.arlo.app
# 7850            com.arlo.app
# 7851            com.arlo.app
# 7852            com.arlo.app
# 7853            com.arlo.app
# 7854            com.arlo.app
# 7855            com.arlo.app
# 7856            com.arlo.app
# 7857            com.arlo.app
# 7858            com.arlo.app
# 7859            com.arlo.app
# 7860            com.arlo.app
# 7861            com.arlo.app
# 7862            com.arlo.app
# 7863            com.arlo.app
# 7864            com.arlo.app
# 7865            com.arlo.app
# 7866            com.arlo.app
# 7867            com.arlo.app
# 7868            com.arlo.app
# 7869            com.arlo.app
# 7870            com.arlo.app
# 7871            com.arlo.app
#
#                                                 content  score  thumbsUpCount  \
# 0     I have the OnePlus 7 Pro phone which features ...      2             24
# 1     I like it so far! It is a great app to use dur...      4              0
# 2     This is a great app, great concept, my only co...      3             18
# 3     It is a very useful and wonderful app over all...      4              0
# 4     Great. Very reminiscent of Skype on computers ...      4             73
# 5     Certain parts of this are great, the concept a...      3            165
# 6     I've used this app just once while talking wit...      5             98
# 7     Fine for quick video chats, but I can't turn o...      2            109
# 8     Cool app to play simple games with friends or ...      2             77
# 9     A couple of people mentioned a lack of securit...      4            135
# 10    I don't rate apps a lot, but I really enjoy th...      5            336
# 11    Confusing interface, and somehow you wind up o...      2             67
# 12    Sadly our first Houseparty experience was an e...      1            184
# 13    This app is a very good app for friends and fa...      5            608
# 14    Great concept We had a lot of fun AT FIRST (an...      3             93
# 15    This all is so much fun and I'm on it all the ...      3             10
# 16    Cant mute the notification sound for this app,...      3              5
# 17    Works great on mobile! Everything working as i...      5            187
# 18    Cool concept, but app layout is bizarre and no...      3              9
# 19    It's ok but would be better if the games were ...      2             72
# 20    I'm currently trying to sign up for the first ...      2              3
# 21    I've used this several times now with friends,...      5             24
# 22    I loved using this app but it no longer works ...      3            276
# 23    Not the best. I had a nice 5-6 hour long chat ...      2             11
# 24    comes great games and it really makes you feel...      5              1
# 25    I just finished a chat with two friends who li...      3             70
# 26    Downloaded this app so me and partner could do...      4             11
# 27    My facebook friends won't load and neither wil...      2             19
# 28    Despite all the negative reviews that state th...      4            593
# 29    Cool concept, doesn't work very well. First, I...      1             14
# ...                                                 ...    ...            ...
# 7842  This system is mediocre at best. Paid extra fo...      3              2
# 7843  This app has a number of good features, and is...      3              3
# 7844  It was easy to install even for someone like m...      4              0
# 7845  Very happy with the battery life. Of course ba...      5              1
# 7846  Update: lowered rating to 1 star because the "...      1              6
# 7847  This app is so slow. Most of the time the pers...      1             28
# 7848  It takes as long as 15 seconds for me to get n...      1              9
# 7849  (1) app keeps crashing in the background, so n...      2             18
# 7850  My biggest thing is the number of times I have...      1              6
# 7851  The app (and associated hardware) performs pre...      3              1
# 7852  Takes so long to buffer and time is delayed. O...      3              3
# 7853  Every time I open the app it says I need to up...      1              4
# 7854  Serious lag, will randomly decide to not show ...      1              3
# 7855  Right idea, poor delivery. The app doesn't alw...      2              3
# 7856  Terribly buggy! When it does actually work (30...      2              2
# 7857  Works excellent, camera picks up a good area a...      4              0
# 7858  Latest update is full of bugs. Hangs for a lon...      1              0
# 7859  Intermittent, doesn't always connect even afte...      2              0
# 7860  Extremely unreliable. Do not plan to use this ...      1             50
# 7861  App does not work with Samsung Multi window fe...      1             11
# 7862  The geofencing is flaky as hell, just like the...      1              9
# 7863  If you want all your cameras to do the same th...      3              6
# 7864  Great video, ease of mounting, sound quality c...      4              0
# 7865  Having installed several Arlo cams for many ye...      1              4
# 7866  The app video never works, it sits there loadi...      1              6
# 7867  This app either crashes or doesn't connect (ju...      1              6
# 7868  I like the cameras however, what's the point i...      1              2
# 7869  We've used one Arlo Pro 2 for about 1.5 years....      3              0
# 7870  Bad. This system feels more like it's in alpha...      1              3
# 7871  Cant believe I bought this. The reaction time ...      1              2
#
#        category
# 0        social
# 1        social
# 2        social
# 3        social
# 4        social
# 5        social
# 6        social
# 7        social
# 8        social
# 9        social
# 10       social
# 11       social
# 12       social
# 13       social
# 14       social
# 15       social
# 16       social
# 17       social
# 18       social
# 19       social
# 20       social
# 21       social
# 22       social
# 23       social
# 24       social
# 25       social
# 26       social
# 27       social
# 28       social
# 29       social
# ...         ...
# 7842  lifestyle
# 7843  lifestyle
# 7844  lifestyle
# 7845  lifestyle
# 7846  lifestyle
# 7847  lifestyle
# 7848  lifestyle
# 7849  lifestyle
# 7850  lifestyle
# 7851  lifestyle
# 7852  lifestyle
# 7853  lifestyle
# 7854  lifestyle
# 7855  lifestyle
# 7856  lifestyle
# 7857  lifestyle
# 7858  lifestyle
# 7859  lifestyle
# 7860  lifestyle
# 7861  lifestyle
# 7862  lifestyle
# 7863  lifestyle
# 7864  lifestyle
# 7865  lifestyle
# 7866  lifestyle
# 7867  lifestyle
# 7868  lifestyle
# 7869  lifestyle
# 7870  lifestyle
# 7871  lifestyle
#
# [7872 rows x 5 columns]
